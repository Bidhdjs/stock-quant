# %%
# 1. 调用 Gemini 生成分析思路（需配置 API Key）
import google.generativeai as genai
import os

# 建议将 KEY 设为 Windows 环境变量，避免写在代码里
# genai.configure(api_key=os.environ.get("GEMINI_API_KEY")) 
genai.configure(api_key="AIzaSyDwALJTKqlTQGUl6I2IZa7L_oEpT3m4geY") 

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("给出一组模拟电商销售数据的Python生成代码，并用Matplotlib画趋势图")
print(response.text)

# 2. 画图体验
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.title("Windows VS Code Plotting")
plt.show() # 图片会直接内嵌在 VS Code 界面里，支持缩放和保存
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\24222\miniforge3\envs\data_analysis\Lib\site-packages\google\api_core\grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File c:\Users\24222\miniforge3\envs\data_analysis\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
# ...

# %%
import sys
import os

# 获取当前 Python 所在的文件夹
current_env_path = sys.prefix

# 推算 mamba 的位置
# Miniforge 通常把 mamba.bat 放在安装目录下的 condabin 文件夹里
mamba_path = os.path.join(current_env_path, "condabin", "mamba.bat")

# 如果不是 base 环境，我们需要往上找两层（假设您现在的环境是在 envs 目录下）
if "envs" in current_env_path:
    # 这一步是为了找到 miniforge3 的根目录
    root_path = os.path.dirname(os.path.dirname(current_env_path))
    mamba_path = os.path.join(root_path, "condabin", "mamba.bat")

print("您的 mamba 路径应该是这个，请复制：")
print("-" * 30)
print(mamba_path)
print("-" * 30)
# Out:
# 您的 mamba 路径应该是这个，请复制：
# ------------------------------
# c:\Users\24222\miniforge3\condabin\mamba.bat
# ------------------------------
